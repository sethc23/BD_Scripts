# %%
from sys import path as sys_path
sys_path.append('/Users/admin/SERVER2/BD_Scripts/geolocation')
from f_nyc_data import parse_NYC_snd_datafile,SND_NON_S_PATH,SND_S_PATH
import pandas as pd
pd.set_option('display.max_rows', 2000)
import numpy as np

from sqlalchemy import create_engine
engine = create_engine(r'postgresql://postgres:postgres@localhost/routing')
BASE_SAVE_PATH = '/Users/admin/Projects/GIS/NYC_gov_data/'

### parse data from NYC BYTES Street Name Directory ("SND")
# fpath = BASE_SAVE_PATH+'pad14b/snd14Bcow.txt'
# save_to_disk = parse_NYC_snd_datafile(fpath)
# print '\nsave_to_disk?\t',save_to_disk

# %%
### Parse/Review NYC SND Data

d = pd.read_csv(SND_NON_S_PATH,index_col=0)
d['sc5'] = d.sc5.map(str)
d = d[d.boro==1].drop(['len_full_name','min_SNL','stn20'],axis=1)
dd = pd.read_csv(SND_S_PATH,index_col=0)
dd['sc5_1'] = dd.progen_b10sc_1.map(lambda s: str(s)[1:6])
dd['sc5_2'] = dd.progen_b10sc_2.map(lambda s: str(s)[1:6])
dd['sc7_1'] = dd.progen_b10sc_1.map(lambda s: str(s)[1:8])
dd['sc7_2'] = dd.progen_b10sc_2.map(lambda s: str(s)[1:8])
dd['scL3_1'] = dd.progen_b10sc_1.map(lambda s: str(s)[8:])
dd['scL3_2'] = dd.progen_b10sc_2.map(lambda s: str(s)[8:])

dd = dd[dd.boro==1].drop(['numeric_ind','len_full_name','Unnamed: 0.1'],axis=1)

# %%
skip_list = ['FDR','F D R','HENRY HUDSON']
reg_pat = r'('+"|".join(skip_list)+r')'

a=d[(d.full_stname.str.contains('12\s'))&
    (d.primary_flag=='P')&
    (d.stname.str.contains('(FDR|HENRY\sHUDSON|F\sD\sR\s)')==False)&
    (d.GFT.map(lambda s: True if s==' ' else False))].sort('GFT')
# a = a.drop(['stname','primary_flag','principal_flag','boro','lgc',
#             'numeric_ind','full_stname','ht_name_type_code'],axis=1)
print len(a)
a
# Out:
# 7
#                                  stname primary_flag principal_flag  boro  \
# 9966   LITTLE WEST   12 STREET                     P              F     1
# 4663   EAST   12 STREET                            P              F     1
# 4992   EAST  112 STREET                            P              F     1
# 89       12 AVENUE                                 P              F     1
# 16672  WEST   12 STREET                            P              F     1
# 16827  WEST  112 STREET                            P              F     1
# 17015  WEST  212 STREET                            P              F     1
#
#          sc5  lgc  spv numeric_ind GFT                       full_stname  \
# 9966   25020    1   10           N      LITTLE WEST   12 STREET
# 4663   17230    1   10           N      EAST   12 STREET
# 4992   19210    1   10           N      EAST  112 STREET
# 89     11112    1   10           N        12 AVENUE
# 16672  34010    1   10           N      WEST   12 STREET
# ...

# %%
b = dd[(dd.stname.str.contains('12\s')==True)].sort('GFT')
# b = b.drop(['stname','boro','num_of_progens','progen_word_1','progen_b10sc_1',
#             'progen_word_2','progen_b10sc_2'],axis=1)
print len(b)
b.sort(['sc5_1','sc5_2'])
# Out:
# 3
#      boro                            stname GFT  num_of_progens progen_word_1  \
# 21      1    12 STREET                        S               2             E
# 355     1   112 STREET                        S               2             E
# 591     1   212 STREET                        S               1             W
#
#     progen_gft_1  progen_b10sc_1 progen_word_2 progen_gft_2 progen_b10sc_2  \
# 21                   11723001010             W                 13401001010
# 355                  11921001010             W                 13601001010
# 591                  13770101010
#
#     clean_name  sc5_1  sc5_2    sc7_1    sc7_2 scL3_1 scL3_2
# 21       12 st  17230  34010  1723001  3401001    010    010
# 355     112 st  19210  36010  1921001  3601001    010    010
# 591     212 st  37701         3770101             010

# %%
a_sc5_list = a.sc5.tolist()
b_sc5_1_list = b.sc5_1.tolist()
b_sc5_2_list = b.sc5_2.tolist()
c=pd.merge(b[b.sc5_1.isin(a_sc5_list)], a[a.sc5.isin(b_sc5_1_list)], 
           how='left', on=None, left_on='sc5_1', right_on='sc5',copy=True)
d=pd.merge(b[b.sc5_2.isin(a_sc5_list)], a[a.sc5.isin(b_sc5_2_list)], 
           how='left', on=None, left_on='sc5_2', right_on='sc5',copy=True)
G = c.append(d,ignore_index=True)
G.sort(['sc5_1','sc5_2'])
# c.drop(['GFT_x','num_of_progens','progen_word_1','progen_gft_1',
#         'progen_word_2','progen_gft_2',
#         'lgc','boro_x','boro_y','numeric_ind',
#         'primary_flag','principal_flag','ht_name_type_code'],axis=1)
# Out:
#   GFT_x progen_gft_1 progen_gft_2             clean_name_x  sc5_1  sc5_2  \
# 0     S                               14 street wb roadbed  17270
# 1     S                            14 st westbound roadbed  17270
# 3     S                               14 street eb roadbed  17270
# 4     S                            14 st eastbound roadbed  17270
# 2     S                                              14 st  17270  34050
# 7     S                                              14 st  17270  34050
# 5     S                                    14 st extension  17280
# 6     S                                14 street extension  17280
#
#      sc7_1    sc7_2 scL3_1 scL3_2    sc5  spv GFT_y       clean_name_y
# 0  1727004             010         17270   10                  e 14 st
# 1  1727004             020         17270   10                  e 14 st
# 3  1727005             010         17270   10                  e 14 st
# ...

# %%
d=pd.merge(b, a, how='left', on=None,
         left_on='sc5_2', right_on='sc5',copy=True)
print len(c)
c
# Out:
# 10
#   GFT_x progen_gft_1 progen_gft_2               clean_name_x  sc5_1  sc5_2  \
# 0     S                                 14 street wb roadbed  17270
# 1     S                              14 st westbound roadbed  17270
# 2     S                                                14 st  17270  34050
# 3     S                                 14 street eb roadbed  17270
# 4     S                              14 st eastbound roadbed  17270
# 5     S                                      14 st extension  17280
# 6     S                                  14 street extension  17280
# 7     S            Z                   14 st fdr drive sb en  10820
# 8     S            Z               14 st sb entrance fdr drv  10820
# 9     S            Z               14 street fdr drive sb en  10820
#
#      sc7_1    sc7_2 scL3_1 scL3_2    sc5  spv GFT_y       clean_name_y
# 0  1727004             010         17270   10                  e 14 st
# ...

# %% [markdown]
# ###Integrate NYC_Bytes' Street Name Directory ("snd")
#
# ####General Notes
# * GFT = Geographic Feature Type
#
# * front-truncated street name = deleting 'east' from east houston st (= GFT = 'S')
#     *  ftsn NOT represented by non-S-type record
#
# * B10SC = Borough 10-digit Street Code  (mostly everything has such code except front-truncated)
#
# * 2 names are aliases only if first 6 bytes of B5SC Boro 5-digit street code are same
#
# * 2 names are part of same structure only if first 8 bytes of B7SC Boro 7-digit street code are same
#
# * WEST 42 STREET is a progenitor of the front-truncated street name 42 STREET
#
# * Only street names (GFT = blank, ‘A’, ‘B’, ‘E’, ‘F’, ‘H’, ‘M’, ‘O’, ‘R’, ‘T’ or ‘Z’) may serve as progenitors
#
# ####Characters Allowed:
#     [a-z0-9A-Z],[-&'/]
#
# ####Borough:
#     1 = MN
#     2 = Bronx
#     3 = Brooklyn
#     4 = Queens
#     5 = Staten Island
#
# ####Geographic Feature ("GFT"):
#     blank None of the below, e.g., either a name of a street that has no hyphenated house numbers
#         and no part of which is within
#         Edgewater Park, or a name of a tunnel, etc
#     A Addressable place name
#     B Name of bridge
#     C Business Improvement Districts
#     D Duplicate Address Pseudo-Street name (DAPS)
#     E Street is entirely within Edgewater Park
#     F Street is partially within Edgewater Park
#     G Non-Addressable Place name (NAP) of a complex
#     H All house numbers on this street are hyphenated
#     I Intersection Name
#     J Non-Physical Boundary Features
#     M Some house numbers on this street are hyphenated, some are not
#     N NAP of a 'stand-alone' geographic feature (not a complex
#         or a constituent entity of a complex)
#     O Shore Line
#     P Pseudo-street name (BEND, CITY LIMIT, DEAD END and their aliases)
#     R Rail line
#     S Front-truncated street name
#     T Tunnel
#     U Miscellaneous Structures
#     X NAP of a constituent entity of a complex Z Ramp
#
# ####Based on above:
#     ignore GFTs equal to B,G,N,O,R,T
#
#     watch GFT's H,M for hyphenated bldg numbers
#
# Not everything in the SND is a street.  The SND also contains:
#
#     -BEND
#     -CITY LIMIT
#     -DEAD END
#     -"Duplicate Address Pseudo-Street" names ("DAPS")
#     -rail lines and shorelines
#     -Place Names:
#
#         -Addressable Place Names
#         -Non-Addressable ("NAPS"), i.e., Bryant Park
#
# >Typical NAP’s include the names
# of islands, parks, airports, bodies
# of water, building complexes,
# major named individual buildings
# etc. Examples: the Manhattan names
# EMPIRE STATE BUILDING, BRYANT PARK
# and CITY HALL, and the >Queens name
# LA GUARDIA AIRPORT. Note that some
# NAP’s (such as EMPIRE STATE
# BUILDING) refer to buildings that
# also have conventional street
# addresses.
#
#         -Intersection Names
#
#
# ####Remove Non-Streets and Paths:
#
# These are all possible values for "lion_ways.feat_type":
#
#     VALUE     DESCRIPTION
#     0      =  street other than vehicle only street
#     *1     =  Railroad
#     *2     =  Water Edge / Shoreline
#     *3     =  Census Block Boundary
#     4      =  (none)
#     5      =  paper street (legally mapped but may not exist)
#     6      =  private street
#     *7     =  District Boundary
#     8      =  physical non-street boundary (cemetary)
#     A      =  alley
#     W      =  path, non-vehicular, addressable
#     C      =  street area adversely possessed by city
#
# Rows with the marked (*) features are removed.

# %%
# d2  = pd.read_csv(SND_S_PATH,index_col=0)
# snd_ns = geoparse(snd_ns,'stname','clean_name')
# snd_ns.to_csv('/Users/admin/Projects/GIS/NYC_gov_data/pad14b/snd14Bcow_non_s_recs.csv')
# snd_s = geoparse(snd_s,'stname','clean_name')
# snd_s.to_csv('/Users/admin/Projects/GIS/NYC_gov_data/pad14b/snd14Bcow_s_recs.csv')

### Data Quality Check

# a=len(snd_ns[snd_ns.primary_flag=='P'])
# b=len(snd_ns[snd_ns.primary_flag=='V'])
# c=len(snd_ns)
# c==a+b # true

# a=len(snd_ns[snd_ns.boro==1])
# b=len(snd_ns[snd_ns.boro==2])
# c=len(snd_ns[snd_ns.boro==3])
# d=len(snd_ns[snd_ns.boro==4])
# e=len(snd_ns[snd_ns.boro==5])
# f=len(snd_ns)
# f==a+b+c+d+e # true

gft_ignore = ['B','G','N','O','R','T']
F = d[(d.boro==1)&(d.primary_flag=='P')&(d.GFT.isin(gft_ignore)==False)] 
F = F.drop(['principal_flag','boro','lgc','spv','len_full_name',
            'min_SNL','stn20','ht_name_type_code'],axis=1)
F = geoparse(F,'full_stname','clean_name')
u = F.clean_name.unique().tolist()

addr_street_col = 'clean_name'

ur,r = match_simple(ur='',r='',df=F,from_label=addr_street_col,show_info=True)
ur,r = match_simple_regex(ur=ur,r=r,df=F,from_label=addr_street_col,show_info=True)
ur,r = match_levenshtein_series(ur=ur,r=r,df=F,from_label=addr_street_col,show_info=True)

print '\n-----------\n-----------\n'
print len(ur),'of',len(F),'streets recognized\t ( ',round(100*float(len(ur)/float(len(F))),2),'% )'


chk = ur.drop(['stname','primary_flag','numeric_ind','GFT'],axis=1)
chk['a_addr'] = chk.bldg_street_idx.map(bldg_idx_addr_map)
chk = chk.ix[:,['sc5','clean_name','a_addr','bldg_street_idx']]
chk


dbm = db_matches = find_address_idx_matches(F_streets)
dbm_addr = dbm.addr.tolist()
addr_idx_map = dict(zip(dbm_addr,dbm.bldg_street_idx.tolist()))
recog_idx = d[F[addr_street_col].isin(dbm_addr)==True].index
ur = d.ix[recog_idx,:]
ur['bldg_street_idx'] = ur.addr_street.map(addr_idx_map)
r = remaining_addr = d[d.index.isin(d.index-recog_idx)].reset_index(drop=True)

# t1.head()

get_bldg_street_idx(F,addr_col='clean_name')

d = snd_ns[(snd_ns.boro==1)&(snd_ns.primary_flag=='P')]
d = d.drop(['Unnamed: 0','Unnamed: 0.1','primary_flag','principal_flag',
                    'len_full_name','min_SNL','stn20','ht_name_type_code'],axis=1)
print len(d)
d = get_addr_body(d,from_label='clean_name').reset_index(drop=True)
d.ix[:100,:]
gft_watch = ['H','M']
ph = poss_hyphenated = mn[mn.GFT.isin(gft_watch)==True]
print len(poss_hyphenated),'rows to watch b/c of hyphenated name'
# mn['chk_hyphenated'] = mn[mn.GFT.isin(gft_watch)==True]
ph.GFT.map(lambda s: bool(re_search('(dobbin)',s))).tolist().count(True)

mn = z[z.mn==True].reset_index(drop=True)


print len(mn[mn.GFT.isin(gft_ignore)==False]),'rows with possible relevant data'


print len(r),'remaining records'
